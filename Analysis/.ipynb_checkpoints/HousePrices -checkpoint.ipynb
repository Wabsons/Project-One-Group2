# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import os as csv 
import random

# %%
# File to load 

Test_to_load = pd.read_csv('../Resources/test.csv')

Train_to_load = pd.read_csv('../Resources/train.csv')

# %%
# Read Data
test_df = (Test_to_load)
train_df = (Train_to_load)

# Merging DataSets
#data_df = pd.merge(test_df, train_df, how='outer', on='Id')

train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#AvgFt_data_df = train_df.loc['SalePrice']
  
filter_saleprice = train_df.filter(items=['SalePrice', 'BedroomAbvGr'])     

Grouped_df = filter_saleprice.groupby('BedroomAbvGr').mean() 

Grouped_df.round()
# Out:
#               SalePrice
# BedroomAbvGr
# 0              221493.0
# 1              173162.0
# 2              158198.0
# 3              181057.0
# 4              220421.0
# 5              180819.0
# 6              143779.0
# 8              200000.0

# %%
# drop Nan columns
new_data_df = train_df.drop(columns=['Alley', 'PoolQC', 'Fence', 'MiscFeature'])
                                    
new_data_df.head(25)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1    2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2    3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3    4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4    5          60       RL         84.0    14260   Pave      IR1         Lvl
# 5    6          50       RL         85.0    14115   Pave      IR1         Lvl
# 6    7          20       RL         75.0    10084   Pave      Reg         Lvl
# 7    8          60       RL          NaN    10382   Pave      IR1         Lvl
# 8    9          50       RM         51.0     6120   Pave      Reg         Lvl
# 9   10         190       RL         50.0     7420   Pave      Reg         Lvl
# 10  11          20       RL         70.0    11200   Pave      Reg         Lvl
# ...

# %%
new_train_data_df = new_data_df.dropna() 

new_train_data_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
# 6   7          20       RL         75.0    10084   Pave      Reg         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
# 6    AllPub    Inside  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
list(new_train_data_df)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
train_df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#calculating the distribution of skewness
plt.hist(train_df.SalePrice, color='blue')
plt.show()

# %%
#scatter plot LotArea/SalePrice
data = pd.concat([new_train_data_df['SalePrice'], new_train_data_df['LotArea']], axis=1)
data.plot.scatter(x='LotArea', y= 'SalePrice', ylim=(0,800000))

# %%
#scatter plot  GrLivarea/SalePrice
data = pd.concat([new_train_data_df['SalePrice'], new_train_data_df['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y= 'SalePrice', ylim=(0,800000),color='red')

# %%
data = pd.concat([new_train_data_df['SalePrice'], new_train_data_df['BedroomAbvGr']], axis=1)
data.plot.scatter(x='BedroomAbvGr', y= 'SalePrice', ylim=(0,800000))

# %%
data = pd.concat([new_train_data_df['SalePrice'], new_train_data_df['TotalBsmtSF']], axis=1)
data.plot.scatter(x='TotalBsmtSF', y= 'SalePrice', ylim=(0,800000),color='g')

# %%
#looking at SaleCondition by constructing and plotting a pivot table

condition_pivot = new_train_data_df.pivot_table(index='SaleCondition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='yellow')
plt.xlabel('Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
#looking at lotconfig by constructing and plotting a pivot table

lot_pivot = new_train_data_df.pivot_table(index='LotConfig', values='SalePrice', aggfunc=np.median)
lot_pivot.plot(kind='bar', color='purple')
plt.xlabel('LotConfig')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()
